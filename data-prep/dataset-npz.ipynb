# %%
# !pip install cupy-cuda12x
# Out:
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.11/dist-packages (13.6.0)
# Requirement already satisfied: numpy<2.6,>=1.22 in /usr/local/lib/python3.11/dist-packages (from cupy-cuda12x) (1.26.4)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.11/dist-packages (from cupy-cuda12x) (0.8.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.6,>=1.22->cupy-cuda12x) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.6,>=1.22->cupy-cuda12x) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.6,>=1.22->cupy-cuda12x) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.6,>=1.22->cupy-cuda12x) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.6,>=1.22->cupy-cuda12x) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.6,>=1.22->cupy-cuda12x) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.6,>=1.22->cupy-cuda12x) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.6,>=1.22->cupy-cuda12x) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.6,>=1.22->cupy-cuda12x) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.6,>=1.22->cupy-cuda12x) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.6,>=1.22->cupy-cuda12x) (2024.2.0)

# %%
import os
import pandas as pd
import h5py
import numpy as np

# === CONFIGURATION ===
data_folder = "/kaggle/input/stanford-earthquake-dataset-stead"   # Path to folder containing .csv and .hdf5 files
output_folder = "/kaggle/working/npz_output"  # Where to save the .npz files
os.makedirs(output_folder, exist_ok=True)

# === LOOP THROUGH FILES ===
for csv_file in os.listdir(data_folder):
    if not csv_file.endswith(".csv"):
        continue

    base_name = os.path.splitext(csv_file)[0]
    hdf5_file = os.path.join(data_folder, f"{base_name}.hdf5")
    csv_path = os.path.join(data_folder, csv_file)

    if not os.path.exists(hdf5_file):
        print(f"⚠️ Skipping {csv_file}: matching HDF5 file not found.")
        continue

    print(f"\n📂 Processing: {csv_file} and {hdf5_file}")

    # --- Step 1: Read CSV ---
    df = pd.read_csv(csv_path)
    print(f"Total events in CSV: {len(df)}")

    # --- Step 2: Filter Events ---
    df = df[
        (df.trace_category == 'earthquake_local') &
        (df.source_distance_km <= 20) &
        (df.source_magnitude > 4)
    ]
    print(f"Selected events: {len(df)}")

    if len(df) == 0:
        continue

    # --- Step 3: Open HDF5 File ---
    with h5py.File(hdf5_file, 'r') as dtfl:
        for idx, trace_name in enumerate(df['trace_name']):
            if f"data/{trace_name}" not in dtfl:
                print(f"⚠️ Trace {trace_name} not found in {hdf5_file}. Skipping.")
                continue

            dataset = dtfl[f"data/{trace_name}"]
            data = np.array(dataset)  # Shape: (N, 3)
            
            # --- Step 4: Extract attributes ---
            attrs = {k: dataset.attrs[k] for k in dataset.attrs.keys()}

            # --- Step 5: Save waveform and metadata ---
            save_name = f"{base_name}_{trace_name}.npz"
            save_path = os.path.join(output_folder, save_name)

            np.savez_compressed(save_path, 
                                waveform=data, 
                                attributes=attrs)

            print(f"✅ Saved {save_name} (shape={data.shape})")

print("\n🎉 All files processed and saved to:", output_folder)
# Out:
# 📂 Processing: merge.csv and /kaggle/input/stanford-earthquake-dataset-stead/merge.hdf5
# /tmp/ipykernel_37/689605949.py:27: DtypeWarning: Columns (7,11,13,14,24,25,26,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# Total events in CSV: 1265657
# Selected events: 352
# ✅ Saved merge_A64.CN_20130711201601_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AC04.C1_20140616231955_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AC04.C1_20140720063145_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AC04.C1_20140720063148_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AKRB.AV_20100820164042_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090406022743_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090406163802_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090406231531_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090407174734_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090407213423_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090408225648_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090409005253_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090409031446_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090409043241_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090409193816_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090413211418_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090418090552_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090423214858_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090622205833_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AQU.MN_20090712083843_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ARG.HL_20040520112658_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ARG.HL_20040820111224_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ARG.HL_20050711172034_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ARSB.KR_20120220022349_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ARSB.KR_20120220022352_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ARSB.KR_20140612030757_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ATE.FR_20130607100710_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AU22.AV_20140312084341_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AU22.AV_20140312084342_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUL.AV_20131228144306_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUL.AV_20140312084339_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUL.AV_20140312084340_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUL.AV_20140312084342_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUQ.AV_20140312084339_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUQ.AV_20140312084340_EV.npz (shape=(6000, 3))
# ✅ Saved merge_AUQ.AV_20140312084342_EV.npz (shape=(6000, 3))
# ✅ Saved merge_B046.PB_20130518134606_EV.npz (shape=(6000, 3))
# ✅ Saved merge_B072.PB_20120806073545_EV.npz (shape=(6000, 3))
# ✅ Saved merge_B073.PB_20120806073544_EV.npz (shape=(6000, 3))
# ✅ Saved merge_B075.PB_20120806073541_EV.npz (shape=(6000, 3))
# ✅ Saved merge_B086.PB_20130311165600_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BBGB.NC_20140821043342_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BCOK.OK_20141013122449_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BKZ.NZ_20070204191429_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BKZ.NZ_20121112100526_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BKZ.NZ_20121112100527_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BMN.LB_20070909013316_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BO02.C1_20140713064314_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BRLK.AK_20080712210638_EV.npz (shape=(6000, 3))
# ✅ Saved merge_BZN.AZ_20130311165601_EV.npz (shape=(6000, 3))
# ✅ Saved merge_C04A.TA_20071127061827_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CBRU.CA_20030226033250_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CBRU.CA_20040921154801_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CHN.CI_20120808062329_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CHN.CI_20120829203057_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CHN.CI_20140329213243_EV.npz (shape=(6000, 3))
# ✅ Saved merge_COLA.IU_20090601053532_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CROK.OK_20141014062615_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CROK.OK_20141114115826_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CVS.BK_20000903083624_EV.npz (shape=(6000, 3))
# ✅ Saved merge_CVS.BK_20060803030805_EV.npz (shape=(6000, 3))
# ✅ Saved merge_DAC.LB_19980306055420_EV.npz (shape=(6000, 3))
# ✅ Saved merge_DID.HP_20110821061426_EV.npz (shape=(6000, 3))
# ✅ Saved merge_DNR.CI_20130311165600_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20080702161846_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20090310193909_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20090607090004_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20100122043729_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20100122105327_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20100212194805_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20100308131155_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20100426142048_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20100426142050_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20101107115407_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20110211175648_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20110211175653_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20120425103403_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EFP.HP_20120425103407_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EVGI.HT_20130523140858_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EVGI.HT_20130523140901_EV.npz (shape=(6000, 3))
# ✅ Saved merge_EVGI.HT_20140613091109_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FALS.AK_20121024065050_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FIB.AK_20050823035813_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FRD.AZ_20100707235328_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20140525224201_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20141113093749_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150331154834_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150331154835_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150331154837_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150331154838_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150404043814_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150404043815_EV.npz (shape=(6000, 3))
# ✅ Saved merge_FSK.HP_20150404043818_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GC02.OK_20141125233246_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20120403072515_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20120403072519_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130723051124_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130723051127_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130805072945_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130805072947_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130807082002_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130807082006_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130807082007_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130807082008_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130907191337_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20130907191341_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20140712065534_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO01.C_20141007050918_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO05.C_20120427175823_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO05.C_20120427175826_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO05.C_20140304112418_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO05.C_20140304112421_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GO05.C_20140607135517_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GR2.CI_20140317132535_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GSTD.AV_20110210142148_EV.npz (shape=(6000, 3))
# ✅ Saved merge_GSTD.AV_20110210142150_EV.npz (shape=(6000, 3))
# ✅ Saved merge_HLL.CI_20140317132529_EV.npz (shape=(6000, 3))
# ✅ Saved merge_I23K.TA_20141021003655_EV.npz (shape=(6000, 3))
# ✅ Saved merge_I23K.TA_20141023163022_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IBP.CI_20100522045313_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IBP.CI_20100615045938_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IKP.CI_20121002082812_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ITM.HL_20040301003554_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ITM.HL_20100120165515_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IVE.AV_20100727091507_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IVE.AV_20100814110309_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IVE.AV_20100915160648_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IVE.AV_20130825174912_EV.npz (shape=(6000, 3))
# ✅ Saved merge_IVE.AV_20130825174915_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KABU.AV_20121022081904_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KABU.AV_20121022081906_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20091116183042_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20100122005027_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20100122043732_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20100122105330_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20100308131154_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20100404220552_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20100426142050_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20120425103405_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20120425103409_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20120921152116_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20130715200750_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20130715200751_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20130715200753_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20130715200754_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20130926023433_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20130926023434_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140124220843_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140124220846_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140129091419_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140204224855_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140204224900_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140608151047_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20140608151048_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20141107171254_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20150120005825_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KALE.HA_20150120005826_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KAN01.GS_20141002180119_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KAN09.GS_20141112213957_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KAN12.GS_20141002180119_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KDJ.KR_20141114012412_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KDJ.KR_20141114020908_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KDJ.KR_20141114024825_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20140310232743_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20140310232746_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20140310232748_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20140310232749_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20140410154640_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141107074134_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141112063131_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141113093747_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141113093751_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141124072026_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141124072712_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20141124154214_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20150331154833_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20150404043812_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20150404043814_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20150404043815_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20150422155530_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF4.HL_20150422155532_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20141108231538_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20141112063130_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20141113093748_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20141124072026_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20141124154219_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150404043812_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150404043813_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150404043815_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150404043816_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150404043817_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150422155529_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150422155530_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150422155532_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150422155533_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEF5.HL_20150422155534_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEK.HL_20130131080403_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KEK.HL_20130131080407_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KTH.AK_20060527180446_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KTH.AK_20110123024957_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KTH.AK_20110123025002_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KTH.AK_20110123233744_EV.npz (shape=(6000, 3))
# ✅ Saved merge_KTH.AK_20110123233747_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20080702161846_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20090310193909_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20090607090001_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20120425103405_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20120425103410_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20120623175230_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20120623175231_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20120921152114_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20120921152118_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20130428044959_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20130715200749_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20130715200750_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20130926023430_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LAKA.HA_20130926023433_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LCG.CI_20140317132532_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LCO.IU_20090417033425_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LGNH.CN_20100222093554_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LGNH.CN_20101112165855_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LOHW.IW_20100805000413_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LOHW.IW_20100817024949_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LOUT.HA_20110906041420_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LOUT.HA_20120217080459_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LOUT.HA_20120217080502_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LTK.HP_20110906041423_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LTK.HP_20120217080502_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LTY.UW_20150218090402_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LTY.UW_20150218090403_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LTY.UW_20150218090405_EV.npz (shape=(6000, 3))
# ✅ Saved merge_LTY.UW_20150218090406_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MAKR.HA_20090916071255_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MCK.AK_20140203163931_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MCK.AK_20140203163935_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MCK.AK_20140427124703_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MLAC.CI_20080628144407_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MLAC.CI_20110824115945_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MLS.CI_20140115093515_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MRKA.HA_20091112072643_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MRKA.HA_20100309020055_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MRKA.HA_20100309025455_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MT05.C1_20140831110653_EV.npz (shape=(6000, 3))
# ✅ Saved merge_MTP.PR_20050822125132_EV.npz (shape=(6000, 3))
# ✅ Saved merge_NBC5.CN_20140804171718_EV.npz (shape=(6000, 3))
# ✅ Saved merge_NIKH.AK_20131107142625_EV.npz (shape=(6000, 3))
# ✅ Saved merge_NIKH.AK_20131107142629_EV.npz (shape=(6000, 3))
# ✅ Saved merge_O09A.TA_20070909013322_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OK029.GS_20140712171142_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OK029.GS_20140819124131_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OK029.GS_20140919172310_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OK029.GS_20140919172315_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OK029.GS_20141013122449_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OKCSW.OK_20140317081331_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OKCSW.OK_20140317081335_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OLI.CI_20120829203055_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OLI.CI_20140329213240_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ONI.GO_20130428000134_EV.npz (shape=(6000, 3))
# ✅ Saved merge_ONI.GO_20130428000136_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OSI.CI_20150104031804_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OSI.CI_20150104031806_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OUR.HT_20120304033108_EV.npz (shape=(6000, 3))
# ✅ Saved merge_OUR.HT_20130215144250_EV.npz (shape=(6000, 3))
# ✅ Saved merge_P01C.TA_20061109083807_EV.npz (shape=(6000, 3))
# ✅ Saved merge_P01C.TA_20070418084216_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PFO.AZ_20130311165558_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PFO.AZ_20130311165602_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PKD.BK_20021112164818_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PKD.BK_20070522113410_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PKD.BK_20120806073543_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PPLA.AK_20120510022314_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PRZ.KR_20130222051216_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PTL.HL_20130604015652_EV.npz (shape=(6000, 3))
# ✅ Saved merge_PYLO.FR_20121013043340_EV.npz (shape=(6000, 3))
# ✅ Saved merge_R06C.TA_20070309031726_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RIN.CI_20140317132534_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RLS.HL_20130611214812_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RLS.HL_20130611214813_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RND.AK_20140629065839_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RND.AK_20150308194257_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RND.AK_20150308194258_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RND.AK_20150308194259_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RND.AK_20150308194300_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RXH.CI_20120826205757_EV.npz (shape=(6000, 3))
# ✅ Saved merge_RXH.CI_20120826233321_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SAO.BK_19930116062934_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SAO.BK_20040316063828_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SAO.BK_20110112085054_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SAOF.FR_20061024173142_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SBC.CI_20130529143759_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SBC.CI_20130529143800_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SDPT.AT_20120318103757_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SDPT.AT_20120318103759_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140124220841_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140124220843_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140129091420_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140129091421_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140130234810_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140204224857_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140204224859_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140418050733_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20140926043327_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20150120005824_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20150120005825_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SERG.HP_20150120005827_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SMF2.CI_20140317132532_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SMRT.NA_20120603003313_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SMRT.NA_20120704212927_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SNET.SV_20140417045143_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SNZO.IU_20010808133724_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SNZO.IU_20040730121314_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SNZO.IU_20090827141046_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SOH.HT_20131011051540_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SOH.HT_20131011051544_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SRN.CI_20120808163314_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SRN.CI_20120829203053_EV.npz (shape=(6000, 3))
# ✅ Saved merge_STVI.PR_20100722000014_EV.npz (shape=(6000, 3))
# ✅ Saved merge_SURF.FR_20140407192657_EV.npz (shape=(6000, 3))
# ✅ Saved merge_T52A.TA_20121110170806_EV.npz (shape=(6000, 3))
# ✅ Saved merge_T52A.TA_20121110170809_EV.npz (shape=(6000, 3))
# ✅ Saved merge_TAFP.AV_20120215230353_EV.npz (shape=(6000, 3))
# ✅ Saved merge_THAL.HA_20090517115857_EV.npz (shape=(6000, 3))
# ✅ Saved merge_THAL.HA_20101009190447_EV.npz (shape=(6000, 3))
# ✅ Saved merge_TPFO.TA_20130311165558_EV.npz (shape=(6000, 3))
# ✅ Saved merge_TPFO.TA_20130311165600_EV.npz (shape=(6000, 3))
# ✅ Saved merge_U05C.TA_20070913005141_EV.npz (shape=(6000, 3))
# ✅ Saved merge_U32A.OK_20141031062254_EV.npz (shape=(6000, 3))
# ✅ Saved merge_U65B.XY_20100923163615_EV.npz (shape=(6000, 3))
# ✅ Saved merge_UPR.HP_20080702161846_EV.npz (shape=(6000, 3))
# ✅ Saved merge_UPR.HP_20090310193907_EV.npz (shape=(6000, 3))
# ✅ Saved merge_UPR.HP_20100122105328_EV.npz (shape=(6000, 3))
# ✅ Saved merge_URZ.NZ_20061128185453_EV.npz (shape=(6000, 3))
# ✅ Saved merge_UWE.HV_20150209181610_EV.npz (shape=(6000, 3))
# ✅ Saved merge_V04C.TA_20061128040634_EV.npz (shape=(6000, 3))
# ✅ Saved merge_VRI.RO_20060216024948_EV.npz (shape=(6000, 3))
# ✅ Saved merge_VRI.RO_20071014025706_EV.npz (shape=(6000, 3))
# ✅ Saved merge_VRI.RO_20120706224809_EV.npz (shape=(6000, 3))
# ✅ Saved merge_VRI.RO_20120706224812_EV.npz (shape=(6000, 3))
# ✅ Saved merge_W43A.TA_20121029123923_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WAT1.AK_20150123201534_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WAT1.AK_20150123201535_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WAT1.AK_20150123201536_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WAT6.AK_20141129210648_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WBS.CI_20130724164558_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WBS.CI_20130825185024_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WCN.NN_20080426064005_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WLT.CI_20120808062329_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WLT.CI_20120829203058_EV.npz (shape=(6000, 3))
# ✅ Saved merge_WSS.CI_20140317132531_EV.npz (shape=(6000, 3))
# ✅ Saved merge_X301.7F_20110228050041_EV.npz (shape=(6000, 3))
# ✅ Saved merge_YHH.WY_20140330123433_EV.npz (shape=(6000, 3))
# ✅ Saved merge_YHH.WY_20140330123435_EV.npz (shape=(6000, 3))
#
# 🎉 All files processed and saved to: /kaggle/working/npz_output

# %%
"""
Upload filtered seismic waveform data (.npz) to Edge Impulse using Python SDK.

Each .npz file must contain:
  - waveform: ndarray of shape (samples, 3)
  - attributes: metadata dict (optional)

This script:
  - Reads earthquake and noise waveform .npz files
  - Builds a consistent data array and label list
  - Uploads to Edge Impulse via upload_numpy()

Author: Nithin Aravindan (Edge AI Seismic Project)
"""

import os
import numpy as np
import edgeimpulse as ei

# === CONFIGURATION ===
EI_API_KEY = "ei_eb03aa1fa9592e163b72614732eecc5756bc5250c1778d48150ca837df74ca23"   # 🔑 Replace this with your actual API key
earthquake_folder = r"C:/Users/nithi/Downloads/_output_/npz_output"
noise_folder = r"C:/Users/nithi/Downloads/_output_/npz_noise_output"
SAMPLE_RATE_HZ = 100  # Adjust if known (e.g., 100Hz means one sample every 10ms)
CATEGORY = "training"  # or "testing"

# --- Initialize Edge Impulse SDK ---
ei.API_KEY = EI_API_KEY

# === Collect all NPZ files ===
def load_npz_data(folder_path, label):
    data_list = []
    labels = []
    for file in os.listdir(folder_path):
        if not file.endswith(".npz"):
            continue
        file_path = os.path.join(folder_path, file)
        npz = np.load(file_path, allow_pickle=True)
        waveform = npz["waveform"]

        # Optional: pad or trim to fixed length
        # Example: enforce 3000 samples
        TARGET_LENGTH = 3000
        if waveform.shape[0] < TARGET_LENGTH:
            pad_len = TARGET_LENGTH - waveform.shape[0]
            waveform = np.pad(waveform, ((0, pad_len), (0, 0)), mode="constant")
        elif waveform.shape[0] > TARGET_LENGTH:
            waveform = waveform[:TARGET_LENGTH, :]

        data_list.append(waveform)
        labels.append(label)
    return data_list, labels


print("📂 Loading earthquake data...")
earthquake_data, earthquake_labels = load_npz_data(earthquake_folder, "earthquake_local")

print("📂 Loading noise data...")
noise_data, noise_labels = load_npz_data(noise_folder, "noise")

# === Combine and convert to numpy array ===
all_data = np.array(earthquake_data + noise_data)
all_labels = earthquake_labels + noise_labels

print(f"✅ Total samples ready for upload: {len(all_labels)}")
print(f"Data shape: {all_data.shape}")  # (num_samples, num_points, 3)

# === Sensor definition ===
sensors = [
    {"name": "E_channel", "units": "counts"},
    {"name": "N_channel", "units": "counts"},
    {"name": "Z_channel", "units": "counts"},
]

# === Upload to Edge Impulse ===
print("\n🚀 Uploading to Edge Impulse...")
response = ei.experimental.data.upload_numpy(
    data=all_data,
    labels=all_labels,
    sensors=sensors,
    sample_rate_ms=1000 / SAMPLE_RATE_HZ,
    metadata={"project": "seismic_ai", "source": "merge_dataset"},
    category=CATEGORY,
)

# === Upload summary ===
if len(response.fails) == 0:
    print("\n🎉 All uploads successful!")
else:
    print(f"\n⚠️ {len(response.fails)} uploads failed:")
    for fail in response.fails:
        print(f"- {fail}")

# %%
import os
import pandas as pd
import h5py
import numpy as np

# === CONFIGURATION ===
data_folder = "/kaggle/input/stanford-earthquake-dataset-stead"    # Folder containing .csv and .hdf5 files
output_folder = "/kaggle/working/npz_noise_output"  # Output folder for noise data
os.makedirs(output_folder, exist_ok=True)

# === LOOP THROUGH FILES ===
for csv_file in os.listdir(data_folder):
    if not csv_file.endswith(".csv"):
        continue

    base_name = os.path.splitext(csv_file)[0]
    hdf5_file = os.path.join(data_folder, f"{base_name}.hdf5")
    csv_path = os.path.join(data_folder, csv_file)

    if not os.path.exists(hdf5_file):
        print(f"⚠️ Skipping {csv_file}: matching HDF5 file not found.")
        continue

    print(f"\n📂 Processing: {csv_file} and {hdf5_file}")

    # --- Step 1: Read CSV ---
    df = pd.read_csv(csv_path)
    print(f"Total events in CSV: {len(df)}")

    # --- Step 2: Filter for Noise Data ---
    # Typically, trace_category column includes 'noise'
    df = df[df.trace_category == 'noise']
    print(f"Selected noise events: {len(df)}")

    if len(df) == 0:
        continue

    # --- Step 3: Open HDF5 File ---
    with h5py.File(hdf5_file, 'r') as dtfl:
        for idx, trace_name in enumerate(df['trace_name']):
            data_path = f"data/{trace_name}"
            if data_path not in dtfl:
                print(f"⚠️ Trace {trace_name} not found in {hdf5_file}. Skipping.")
                continue

            dataset = dtfl[data_path]
            data = np.array(dataset)  # (samples, 3 channels)

            # --- Step 4: Extract attributes ---
            attrs = {k: dataset.attrs[k] for k in dataset.attrs.keys()}

            # --- Step 5: Save waveform and metadata ---
            save_name = f"{base_name}_{trace_name}_noise.npz"
            save_path = os.path.join(output_folder, save_name)

            np.savez_compressed(save_path,
                                waveform=data,
                                attributes=attrs)

            print(f"✅ Saved {save_name} (shape={data.shape})")

print("\n🎉 All noise waveforms processed and saved to:", output_folder)
